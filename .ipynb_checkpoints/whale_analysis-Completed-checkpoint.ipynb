# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(whale_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns = whale_returns.dropna().copy()
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(algo_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns = algo_returns.dropna().copy()
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("Resources/sp500_history.csv")
sp500_returns = pd.read_csv(sp500_history_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_returns.sort_index(inplace=True)
sp500_returns
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93
# ...              ...
# 2019-04-16  $2907.06
# 2019-04-17  $2900.45
# 2019-04-18  $2905.03
# 2019-04-22  $2907.97
# 2019-04-23  $2933.68
#
# [1649 rows x 1 columns]

# %%
# Check Data Types
whale_returns.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
algo_returns.dtypes
# Out:
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
sp500_returns.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_returns["Close"] = sp500_returns["Close"].str.replace("$", "")
sp500_returns["Close"]
# Out:
# Date
# 2012-10-01    1444.49
# 2012-10-02    1445.75
# 2012-10-03    1450.99
# 2012-10-04    1461.40
# 2012-10-05    1460.93
#                ...
# 2019-04-16    2907.06
# 2019-04-17    2900.45
# 2019-04-18    2905.03
# 2019-04-22    2907.97
# 2019-04-23    2933.68
# Name: Close, Length: 1649, dtype: object

# %%
# Fix Data Types
sp500_returns["Close"] = sp500_returns["Close"].astype("float")
sp500_returns.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
# Calculate the daily return using the 'shift()' function

sp500daily_returns = sp500_returns.pct_change()
sp500daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500daily_returns.dropna().copy()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Rename Column
sp500daily_returns.rename(columns={'Close':'S&P 500'}, inplace=True)
sp500daily_returns.tail()
# Out:
#              S&P 500
# Date
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
combined_returns = pd.concat([whale_returns, algo_returns, sp500daily_returns], axis="columns", join="inner")
combined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
combined_returns.plot(figsize=(20,10), title='Daily Returns')

# %%
# Calculate cumulative returns
cumulative_returns = (1 + combined_returns).cumprod()
cumulative_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2   S&P 500
# Date
# 2015-03-03  0.999051  0.995461
# 2015-03-04  1.001464  0.991093
# 2015-03-05  1.005794  0.992278
# ...

# %%
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10), title='Cumulative Returns')

# %% [markdown]
# #### ANSWER: As of end of the data timeframe, only Berkshire Hathaway Inc and Algo 1 portfolios have outperformed the S&P 500

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
combined_returns.plot.box(figsize=(20,10), title='Portfolio Risk')

# %% [markdown]
# #### ANSWER: Berkshire Hathaway has the largest spread, and Algo 1 has the smallest spread.

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
daily_std = combined_returns.std()
daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
daily_std = daily_std.sort_values(ascending=False)
daily_std
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# S&P 500                        0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007620
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %% [markdown]
# #### ANSWER: Berkshire Hathaway and Tiger Global Management have higher risk than the S&P 500

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252)
annualized_std
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P 500                        0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
combined_returns.rolling(window=21).std().plot(figsize=(20,10), title='21-Day Rolling Standard Deviation')

# %% [markdown]
# #### ANSWER: Portfolio risk generally follows the S&P 500, with the exception of Berkshire Hathaway, which periodically showed more pronounced risk increases than the market, and Tiger Global Management, which sowed a few peaks in risk that were not consistent with fluctuations in the market or the rest of the portfolios. On the other hand, Paulson & Co Inc., was consistently below the risk level of the S&P 500 and often had the lowest risk of all portfolios.

# %%
# Construct a correlation table
correlation = combined_returns.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Use the `heatmap` function to visualize correlations
sns.heatmap(correlation, vmin=-1, vmax=1)

# %% [markdown]
# #### ANSWER: Algo 1 showed the highest correlation with the S&P 500

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)

# Calculate 30-day rolling covariance of Algo 1 vs. S&P 500
rolling_covariance = combined_returns['Algo 1'].rolling(window=21).cov(combined_returns['S&P 500'])

# Calculate 30-day rolling variance of S&P 500
rolling_variance = combined_returns['S&P 500'].rolling(window=21).var()

# Calculate 30-day rolling beta of Algo 2 and plot the data
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Algo 1 Beta')

# %% [markdown]
# #### ANSWER: Algo 1 seems highly sensitive to movements in the S&P 500

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
combined_returns.ewm(span=21).mean(window=21).plot(figsize=(20,10), title = 'Exponentially Weighted Average')

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
sharpe_ratios = (combined_returns.mean() * 252) / (combined_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios", figsize=(20,10), fontsize=(13))

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?
# Type your answer here:

# %% [markdown]
# ##### ANSWER: Yes, Algo 1 outperforms both, 'the market' and the whales. And Algo 2 outperforms most whales, except Berkshire Hathaway, and does not outperform the S&P 500. As a combined portfolio, the Algos outperform 'the market' and the whales.

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# Add 'Symbol' column
# Rename Index and 'Close' column
# Reset order of columns
goog_stock_csv = Path("Resources/GOOG_Stock_Prices.csv")
goog_stock = pd.read_csv(goog_stock_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
goog_stock['Symbol'] = 'GOOG'
goog_stock = goog_stock.rename(columns={'Close':'NOCP'}, index={'Date':'Trade DATE'})
goog_stock = goog_stock[['Symbol','NOCP']]
goog_stock.head()
# Out:
#            Symbol    NOCP
# Date
# 2017-08-01   GOOG  930.83
# 2017-08-02   GOOG  930.39
# 2017-08-03   GOOG  923.65
# 2017-08-04   GOOG  927.96
# 2017-08-07   GOOG  929.36

# %%
# Read the second stock
# Add 'Symbol' column
# Rename Index and 'Close' column
# Reset order of columns
amzn_stock_csv = Path("Resources/AMZN_Stock_Prices.csv")
amzn_stock = pd.read_csv(amzn_stock_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
amzn_stock['Symbol'] = 'AMZN'
amzn_stock = amzn_stock.rename(columns={'Close':'NOCP'}, index={'Date':'Trade DATE'})
amzn_stock = amzn_stock[['Symbol','NOCP']]
amzn_stock.head()
# Out:
#            Symbol    NOCP
# Date
# 2017-08-01   AMZN  996.19
# 2017-08-02   AMZN  995.89
# 2017-08-03   AMZN  986.92
# 2017-08-04   AMZN  987.58
# 2017-08-07   AMZN  992.27

# %%
# Read the third stock
# Add 'Symbol' column
# Rename Index and 'Close' column
# Reset order of columns
jpm_stock_csv = Path("Resources/JPM_Stock_Prices.csv")
jpm_stock = pd.read_csv(jpm_stock_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
jpm_stock['Symbol'] = 'JPM'
jpm_stock = jpm_stock.rename(columns={'Close':'NOCP'}, index={'Date':'Trade DATE'})
jpm_stock = jpm_stock[['Symbol','NOCP']]
jpm_stock.head()
# Out:
#            Symbol   NOCP
# Date
# 2017-08-01    JPM  93.03
# 2017-08-02    JPM  93.11
# 2017-08-03    JPM  92.50
# 2017-08-04    JPM  93.66
# 2017-08-07    JPM  94.02

# %%
# Concatenate all stocks into a single DataFrame
my_portfolio = pd.concat([goog_stock, amzn_stock, jpm_stock], axis="rows", join="inner")
my_portfolio.head()
# Out:
#            Symbol    NOCP
# Date
# 2017-08-01   GOOG  930.83
# 2017-08-02   GOOG  930.39
# 2017-08-03   GOOG  923.65
# 2017-08-04   GOOG  927.96
# 2017-08-07   GOOG  929.36

# %%
# Reset the index
my_portfolio = my_portfolio.reset_index()
my_portfolio.head()
# Out:
#         Date Symbol    NOCP
# 0 2017-08-01   GOOG  930.83
# 1 2017-08-02   GOOG  930.39
# 2 2017-08-03   GOOG  923.65
# 3 2017-08-04   GOOG  927.96
# 4 2017-08-07   GOOG  929.36

# %%
# Pivot so that each column of prices represents a unique symbol
my_portfolio = my_portfolio.pivot_table(values="NOCP", index="Date", columns="Symbol")
my_portfolio.head()
# Out:
# Symbol        AMZN    GOOG    JPM
# Date
# 2017-08-01  996.19  930.83  93.03
# 2017-08-02  995.89  930.39  93.11
# 2017-08-03  986.92  923.65  92.50
# 2017-08-04  987.58  927.96  93.66
# 2017-08-07  992.27  929.36  94.02

# %%
# Calculate returns for my portfolio
my_returns = my_portfolio.pct_change()
my_returns.head()
# Out:
# Symbol          AMZN      GOOG       JPM
# Date
# 2017-08-01       NaN       NaN       NaN
# 2017-08-02 -0.000301 -0.000473  0.000860
# 2017-08-03 -0.009007 -0.007244 -0.006551
# 2017-08-04  0.000669  0.004666  0.012541
# 2017-08-07  0.004749  0.001509  0.003844

# %%
# Drop Nulls
my_returns.dropna(inplace=True)
my_returns.head()
# Out:
# Symbol          AMZN      GOOG       JPM
# Date
# 2017-08-02 -0.000301 -0.000473  0.000860
# 2017-08-03 -0.009007 -0.007244 -0.006551
# 2017-08-04  0.000669  0.004666  0.012541
# 2017-08-07  0.004749  0.001509  0.003844
# 2017-08-08 -0.002449 -0.002765 -0.003616

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
weighted_returns = my_returns.dot(weights)
weighted_returns.head()
# Out:
# Date
# 2017-08-02    0.000029
# 2017-08-03   -0.007601
# 2017-08-04    0.005959
# 2017-08-07    0.003367
# 2017-08-08   -0.002944
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
all_returns1 = pd.concat([combined_returns, weighted_returns], axis="columns", join="inner")
all_returns1
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2017-08-02                  -0.003726           -0.009155
# 2017-08-03                  -0.003551           -0.023275
# 2017-08-04                  -0.002340           -0.014548
# 2017-08-07                   0.000102           -0.011105
# 2017-08-08                  -0.000553           -0.006067
# ...                               ...                 ...
# 2018-10-05                  -0.010609           -0.004303
# 2018-10-08                  -0.003268           -0.000671
# 2018-10-09                   0.001613           -0.000649
# 2018-10-10                  -0.029343           -0.010970
# 2018-10-11                  -0.012847           -0.013790
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2017-08-02                     0.001075               -0.007844 -0.002310
# 2017-08-03                    -0.004192                0.002081  0.000090
# ...

# %%
# Rename index
all_returns1.rename_axis("Trade DATE", axis='index', inplace=True)
all_returns1.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Trade DATE
# 2017-08-02                  -0.003726           -0.009155
# 2017-08-03                  -0.003551           -0.023275
# 2017-08-04                  -0.002340           -0.014548
# 2017-08-07                   0.000102           -0.011105
# 2017-08-08                  -0.000553           -0.006067
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Trade DATE
# 2017-08-02                     0.001075               -0.007844 -0.002310
# 2017-08-03                    -0.004192                0.002081  0.000090
# 2017-08-04                     0.001838                0.006978  0.004757
# 2017-08-07                     0.002603                0.010465 -0.005613
# 2017-08-08                    -0.007679                0.003090 -0.004973
#
#               Algo 2   S&P 500         0
# Trade DATE
# 2017-08-02 -0.006011  0.000493  0.000029
# 2017-08-03 -0.004730 -0.002184 -0.007601
# ...

# %%
# Rename columns
all_returns1.columns = ['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO INC', 'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'ALGO 1', 'ALGO 2', 'S&P 500', 'MY PORTFOLIO']
all_returns1.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# Trade DATE
# 2017-08-02                  -0.003726         -0.009155
# 2017-08-03                  -0.003551         -0.023275
# 2017-08-04                  -0.002340         -0.014548
# 2017-08-07                   0.000102         -0.011105
# 2017-08-08                  -0.000553         -0.006067
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    ALGO 1  \
# Trade DATE
# 2017-08-02                     0.001075               -0.007844 -0.002310
# 2017-08-03                    -0.004192                0.002081  0.000090
# 2017-08-04                     0.001838                0.006978  0.004757
# 2017-08-07                     0.002603                0.010465 -0.005613
# 2017-08-08                    -0.007679                0.003090 -0.004973
#
#               ALGO 2   S&P 500  MY PORTFOLIO
# Trade DATE
# 2017-08-02 -0.006011  0.000493      0.000029
# 2017-08-03 -0.004730 -0.002184     -0.007601
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_returns1.dropna(inplace=True)
all_returns1.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# Trade DATE
# 2017-08-02                  -0.003726         -0.009155
# 2017-08-03                  -0.003551         -0.023275
# 2017-08-04                  -0.002340         -0.014548
# 2017-08-07                   0.000102         -0.011105
# 2017-08-08                  -0.000553         -0.006067
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    ALGO 1  \
# Trade DATE
# 2017-08-02                     0.001075               -0.007844 -0.002310
# 2017-08-03                    -0.004192                0.002081  0.000090
# 2017-08-04                     0.001838                0.006978  0.004757
# 2017-08-07                     0.002603                0.010465 -0.005613
# 2017-08-08                    -0.007679                0.003090 -0.004973
#
#               ALGO 2   S&P 500  MY PORTFOLIO
# Trade DATE
# 2017-08-02 -0.006011  0.000493      0.000029
# 2017-08-03 -0.004730 -0.002184     -0.007601
# ...

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Calculate risk
all_daily_std = all_returns1.std()
all_daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007224
# PAULSON & CO INC               0.006416
# TIGER GLOBAL MANAGEMENT LLC    0.009864
# BERKSHIRE HATHAWAY INC         0.011012
# ALGO 1                         0.004980
# ALGO 2                         0.006835
# S&P 500                        0.007743
# MY PORTFOLIO                   0.011081
# dtype: float64

# %%
# Calculate volatility
volatility = all_returns1.std() * np.sqrt(252)
volatility
# Out:
# SOROS FUND MANAGEMENT LLC      0.114675
# PAULSON & CO INC               0.101853
# TIGER GLOBAL MANAGEMENT LLC    0.156593
# BERKSHIRE HATHAWAY INC         0.174813
# ALGO 1                         0.079061
# ALGO 2                         0.108498
# S&P 500                        0.122924
# MY PORTFOLIO                   0.175904
# dtype: float64

# %%
# Plot rolling Standard Deviation
all_returns1.rolling(window=21).std().plot(figsize=(20,10), title='21-Day Rolling Standard Deviation')

# %%
# Annualized Sharpe Ratios
all_sharpe_ratios = (all_returns1.mean() * 252) / (all_returns1.std() * np.sqrt(252))
all_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC     -0.448502
# PAULSON & CO INC              -0.845820
# TIGER GLOBAL MANAGEMENT LLC   -1.286584
# BERKSHIRE HATHAWAY INC         0.087740
# ALGO 1                         1.050182
# ALGO 2                         0.591885
# S&P 500                        0.719690
# MY PORTFOLIO                   1.716564
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
all_sharpe_ratios.plot(kind="bar", figsize=(20,10))

# %%
# Create a correlation analysis
all_correlation = all_returns1.corr()
all_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# SOROS FUND MANAGEMENT LLC                     1.000000          0.636877
# PAULSON & CO INC                              0.636877          1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.537437          0.477348
# BERKSHIRE HATHAWAY INC                        0.686400          0.473255
# ALGO 1                                        0.196937          0.187163
# ALGO 2                                        0.748925          0.655126
# S&P 500                                       0.762376          0.655420
# MY PORTFOLIO                                  0.600437          0.489753
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.537437
# PAULSON & CO INC                                0.477348
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.392088
# ...

# %%
# Use the `heatmap` function to visualize correlation of all returns
sns.heatmap(all_correlation, vmin=-1, vmax=1)

# %%
# Calculate rolling covariance
rolling_covariance = all_returns1['MY PORTFOLIO'].rolling(window=30).cov(all_returns1['S&P 500'])
rolling_covariance.plot(figsize=(20, 10), title='Rolling 30-Day Covariance of Custom Portfolio Returns vs. S&P 500 Returns')

# %%
# Calculate 30-day rolling variance of S&P 500
rolling_variance = all_returns1['S&P 500'].rolling(window=30).var()
rolling_variance.plot(figsize=(20, 10), title='Rolling 30-Day Variance of S&P 500 Returns')

# %%
# Calculate 30-day rolling beta of MY PORTFOLIO and plot the data
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 30-Day Beta of MY PORTFOLIO')

# %% [markdown]
# #### ANSWER: While My Portfolio was overall riskier and more volatile than the market, the total Sharpe Ratio value and the down-trending value of the rolling 30-Day Beta showed that this is a portfolio moving in the right direction.
